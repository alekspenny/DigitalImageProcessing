# %% [markdown]
# **Основной задачей было произвести перевод изображения в google и yandex переводчиках**

# %% [markdown]
# ![lab4.jpg](data:image/jpeg;base64,...)

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import sys
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# Изменим стандартный размер графиков matplotlib
plt.rcParams["figure.figsize"] = [6, 4]

# %%
image1 = cv.imread('lab4.jpg')
gray_image1 = cv.cvtColor(image1, cv.COLOR_BGR2GRAY)
channels = [0]
histSize = [256]
range = [0, 256]

gs = plt.GridSpec(1, 2)
plt.figure(figsize=(10, 8))
plt.subplot(gs[0])
plt.imshow(gray_image1, cmap='gray')
plt.xticks([]), plt.yticks([])
plt.subplot(gs[1])
plt.hist(gray_image1.reshape(-1), 256, range)
plt.show()
# Out:
# /tmp/ipython-input-100025843.py:13: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(gray_image1.reshape(-1), 256, range)

# %%
threshold = 100
image = gray_image1

ret, thresh1 = cv.threshold(image, threshold, 255, cv.THRESH_BINARY)

plt.figure(figsize=(15, 8))
plt.imshow(thresh1, 'gray', vmin=0, vmax=255)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1078.5), np.float64(94.5), np.float64(-0.5))

# %% [markdown]
# Получнный результат в google переводчике

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# полученный результат в translate.yandex

# %% [markdown]
# ![lab4_2ya.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение_2026-01-12_135124328.png](data:image/png;base64,...)

# %%
res1 = cv.imread('lab4_1g.png')
res2 = cv.imread('lab4_2ya.png')
gs = plt.GridSpec(1, 2)
plt.figure(figsize=(14, 5))
plt.subplot(gs[0])
plt.imshow(res1, cmap='gray')
plt.axis("off")
plt.subplot(gs[1])
plt.imshow(res2, cmap='gray')
plt.axis("off")
plt.show()
